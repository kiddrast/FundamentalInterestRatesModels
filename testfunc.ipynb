# %%
import numpy as np
import pandas as pd
from functions import generate_ar, fit_ar_ols #, fit_ar_ML_normal

# %%
data = generate_ar(steps=100000, paths=2, a=np.array([0.2, 0.9, 0.1]), start=0, dist='normal', error_var=1)
# Out:
#   0%|          | 0/99998 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = generate_ar(steps=100000, paths=2, a=np.array([0.2, 0.9, 0.1]), start=0, dist='normal', error_var=1)
#
# File c:\Users\alber\python_projects\fundamentals_of_interest_rates\functions.py:49, in generate_ar(steps, paths, a, start, dist, error_var, degree_f, wald_mean)
#      47 # Fill data
#      48 for i in trange(p, steps):
# ---> 49     data[i,:] = a[0] + a[1:].T @ data[i-1:i-p-1:-1, :] + epsilon[i,:]
#      51 print(f'{paths} different AR({p}) processes of {steps - p + 2} steps have been generated with increments following {dist} distribution')
#      53 return data
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 0 is different from 2)

# %%
fit_ar_ols(data, 2)
# Out:
# array([[0.20713011],
#        [0.90064343],
#        [0.09935442]])
